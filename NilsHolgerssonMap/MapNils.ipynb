# %%
from dash import html, dcc, Input, Output
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
import folium
from folium import plugins

# %%
m = folium.Map(location=[61.800453,16.582614],
               tiles=f"https://api.mapbox.com/styles/v1/geonie/ckwncbbrd0yrr14s9jxw55m7f/tiles/256/{{z}}/{{x}}/{{y}}@2x?access_token=pk.eyJ1IjoiZ2VvbmllIiwiYSI6ImNrd25ieHlvczJpbngycG52djFybmpwbmoifQ.IipoXG1Ioqw4iGxjGeXLWA",
               attr='My Data Attribution',
               zoom_start=4
)
#m

# %%
icon1 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=1,
    inner_icon_style="margin-top:0;",
)
icon2 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=2,
    inner_icon_style="margin-top:0;",
)
icon3 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=3,
    inner_icon_style="margin-top:0;",
)
icon4 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=4,
    inner_icon_style="margin-top:0;",
)
icon5 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=5,
    inner_icon_style="margin-top:0;",
)
icon6 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=6,
    inner_icon_style="margin-top:0;",
)
icon7 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=7,
    inner_icon_style="margin-top:0;",
)
icon8 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=8,
    inner_icon_style="margin-top:0;",
)
icon9 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=9,
    inner_icon_style="margin-top:0;",
)
icon10 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=10,
    inner_icon_style="margin-top:0;",
)
icon11 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=11,
    inner_icon_style="margin-top:0;",
)
icon12 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=12,
    inner_icon_style="margin-top:0;",
)
icon13 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=13,
    inner_icon_style="margin-top:0;",
)
icon14 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=14,
    inner_icon_style="margin-top:0;",
)
icon15 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=15,
    inner_icon_style="margin-top:0;",
)
icon16 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=16,
    inner_icon_style="margin-top:0;",
)
icon17 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=17,
    inner_icon_style="margin-top:0;",
)
icon18 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=18,
    inner_icon_style="margin-top:0;",
)
icon19 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=19,
    inner_icon_style="margin-top:0;",
)
icon20 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=20,
    inner_icon_style="margin-top:0;",
)
icon21 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=21,
    inner_icon_style="margin-top:0;",
)
icon22 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=22,
    inner_icon_style="margin-top:0;",
)
icon23 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=23,
    inner_icon_style="margin-top:0;",
)
icon24 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=24,
    inner_icon_style="margin-top:0;",
)
icon25 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=25,
    inner_icon_style="margin-top:0;",
)
icon26 = plugins.BeautifyIcon(
    border_color="#00ABDC",
    text_color="#00ABDC",
    number=26,
    inner_icon_style="margin-top:0;",
)

# %%
popup1 = folium.Popup("""<h2>Destination 1 Västra Vemmenhög</h2><br/>
              A small village in Skåne. This is where Nils Holgersson's journey begins <br/>
              """, max_width=500)

popup2 = folium.Popup("""<h2>Destination 2 Vittskövle Castle</h2><br/>
              Vittskövle Castle is a very well preserved Renaissance castle near Kristianstad built in 1550. <br/>
              """, max_width=500)

popup3 = folium.Popup("""<h2>Destination 3 Glimmingehus</h2><br/>
              Glimmingehus is one of the best preserved medieval castles in Skanidinavia. <br/>
              <a href="https://www.raa.se/evenemang-och-upplevelser/upplev-kulturarvet/glimmingehus/" target="_blank">Check out Glimmingehus</a>'             
              """, max_width=500)

popup4 = folium.Popup("""<h2>Destination 4 Kullaberg</h2><br/>
              The landscape of the Kullaberg is very diverse. Originally, the mountain was probably wooded. The mountain was apparently also used by people in the Stone Age. There are many caves to discover along the coastline and Carl von Linné travelled to Kullaberg.<br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Kullaberg.JPG" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup5 = folium.Popup("""<h2>Destination 5 Karlskrona</h2><br/>
              The first city Nils sees in his life is Karlskrona. There he also meets the life-size wooden sculpture Gubben Rosenbom (The Old Rosenbom). This has stood there for around 250 years in front of the Admiralty Church Ulrica Pia in Karlskrona. The colorful sculpture in the shape of an old man in the uniform of a boatman dates from around 1750 and serves as a money collection box for alms. If you flip away the hat of the sculpture, you can put coins into the figure.<br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/karlskrona.png" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup6 = folium.Popup("""<h2>Destination 6 Öland</h2><br/>
              Öland is an island off the southeastern coast of Sweden. On its west coast stands Borgholm Castle, the ruins of a structure that has been rebuilt several times since the 12th century. Nearby is Solliden Castle, the summer residence of the Swedish royal family, with its beautiful gardens and delicious cakes. Southern Öland is dominated by Stora Alvaret, a wide limestone plateau known for its biodiversity.<br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Oeland1.JPG" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/öland.jpg" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup7 = folium.Popup("""<h2>Destination 7 Gotland</h2><br/>
              Gotland, Sweden's largest island and is located in the Baltic Sea. The capital Visby experienced its heyday in the Middle Ages and is a UNESCO World Heritage Site due to its historic city center. The cult series "Pippi Longstocking" was largely filmed on Gotland and the Villa Kunterbunt can be visited. When visiting Gotland, I can especially recommend the north of the island. The stone surf pillars "Raukar" are limestone pillars that were formed by natural erosion during the last ice age. You can see them frequently on the island, and the most famous ones have even been given names.<br/>
              """, max_width=500)

popup8 = folium.Popup("""<h2>Destination 8 Småland</h2><br/>
              Småland is a historical province in southern Sweden. For children there is much to discover here, such as Nils Holgersson World and Astrid Lindgren's World in Vimmerby. Also in Småland is the town of Gränna, home of Sweden's world-famous candy canes.<br/>
              """, max_width=500)

popup9 = folium.Popup("""<h2>Destination 9 Kolmården</h2><br/>
              We reach the boggy forests of Kolmarden. Kolmården is a forested ridge in Sweden southwest of Nyköping. In Kolmården there are a number of well-preserved finds from Swedish prehistory. In the Stone Age, what are now mountain peaks were islands in the Baltic Sea, used by Stone Age people as dwellings or resting places. For example, pieces of pottery with distinctive depressions typical of Scandinavia in the 4th millennium BC have been found near Säter.<br/>
              """, max_width=500)

popup10 = folium.Popup("""<h2>Destination 10 Stora Djulö</h2><br/>
             During a night adventure, Nils enters a magical garden tended by the gardener "Mr. Karl". The garden is itself a miniature version of Södermanland. Stora Djulö is now a delightful café in an old manor house.<br/>
             <a href="https://storadjulo.se/" target="_blank">Check out Stora Djulö</a>""", max_width=500)

popup11 = folium.Popup("""<h2>Destination 11 Närke</h2><br/>
              Närke is located in the heart of Sweden and is one of the smallest provinces in the country. According to tradition, in Närke, and only here, there was a weather witch named Ysätter-Kajsa. This witch loved wind and storm and danced to it on the plain of Närke. Ysätter-Kajsa and her mischief were immortalized by Selma Lagerlöf in her famous novel "The Wonderful Journey of Little Nils Holgersson".<br/>
              """, max_width=500)

popup12 = folium.Popup("""<h2>Destination 12 Bergslagen, Västmanland</h2><br/>
              Bergslagen is an area in central Sweden. It is known as the historic heartland of Swedish mining, metallurgy and industry. During the 20th century, most of the mines were closed, and in 2020, only three mines are still in use in the region. I can recommend a visit to the Sala underground silver mine in Västmanland. <br/>
              <a href="https://www.salasilvergruva.se/" target="_blank">Check out Sala Silvergruva</a>""", max_width=500)

popup13 = folium.Popup("""<h2>Destination 13 Falun</h2><br/>
              Falun is a town in the Swedish province of Dalarnas. The town in Dalarna, famous for its copper mine. In the 17th and 18th centuries, the mine "Stora Kopparberget" was the largest copper mine in the world. The pigment Falun red, extracted from the copper mine in Falun, became popular as an exterior paint from the 16th century onwards, as it gave color to the wooden houses that were prevalent in Sweden. Selma Lagerlöf herself spent most of her life in Falun. The building where she once lived has been demolished, but many of her personal belongings, including her library and study, are now in the Dalarna Museum.<br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Falun.jpg" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup14 = folium.Popup("""<h2>Destination 14 Siljansbygden</h2><br/>
              In this region, whose folk culture is often considered the epitome of Swedishness, Nils sees a traditional Walpurgis Night celebration. Dalarna is home to the Dala horses. Here more about the history of the Dala horses:<br/>
              <a href="https://www.theswedishwoodenhorse.com/dala-horse-history" target="_blank">Check out the history of Dala Horses</a>""", max_width=500)

popup15 = folium.Popup("""<h2>Destination 15 Uppsala</h2><br/>
              In this "city ruled by wisdom," Nils meets various archetypal students and explores Swedish student culture. Lagerlöf was an honorary doctor of Uppsala University and an honorary member of Wermland's Nation. Uppsala is a city near Stockholm in Sweden. It is known for Uppsala University, which was founded in the 15th century. As an Augsburg resident, I would also like to mention the Gustavianum here. The magnificent Augsburg Cabinet of Curiosities was a gift from the city of Augsburg to King Gustav II Adolf (1632).<br/>
              """, max_width=500)

popup16 = folium.Popup("""<h2>Destination 16 Stockholm archipelago</h2><br/>
              Species richness on Stockholm archipelago, see Heatmap, zoom in<br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/sch%C3%A4ren.jpg" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup17 = folium.Popup("""<h2>Destination 17 Stockholm</h2><br/>
              Stockholm is the capital of Sweden and includes 14 islands of a large archipelago in the Baltic Sea, connected by more than 50 bridges. When visiting Stockholm I can highly recommend a visit to the Vasa Museum and the Nobel Museum. The Vasa was a Swedish galleon that was one of the largest and most heavily armed warships of its time. Already at the beginning of her maiden voyage on August 10, 1628, the Vasa sank after only about 1300 meters of sailing in a normal sea state due to serious structural instability.<br/>
              <a href="https://www.vasamuseet.se/en" target="_blank">Check out the history of Vasa</a>
              <a href="https://nobelprizemuseum.se/en/" target="_blank">Check out the nobel prize museum</a>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Stockholm1.JPG" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Stockholm2.JPG" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup18 = folium.Popup("""<h2>Destination 18 Delsbo, Hudiksvall</h2><br/>
              Here Nils sees "Fäboddrift", the traditional cattle breeding in northern Sweden. Hudiksvall is a small town founded in 1582 as a trading post. Although it lost trade to other coastal towns, suffered ten devastating fires, and was sacked by Russian troops in 1721, Hudiksvall managed to maintain its position as an important regional town. In the 18th century, due to its friendliness and lively social life, the town was given the name Glada Hudik, which has lasted to this day.<br/>
              """, max_width=500)

popup19 = folium.Popup("""<h2>Destination 19 Västernorrland County</h2><br/>
              Here, Nils takes a look at forestry and witnesses a large forest fire. The region is dominated by forests. I can highly recommend a side trip to the High Coast. <br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/P7080188.JPG" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/P7080249.JPG" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup20 = folium.Popup("""<h2>Destination 20 Gällivare</h2><br/>
              Gällivare is located 70 kilometers north of the Arctic Circle. Here you also slowly get closer and closer to Santa Claus. Near Gällivare are also the national parks Muddus and Stora Sjöfallet, especially Stora Sjöfallet I can highly recommend for an excursion. <br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Polarkreis.JPG" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Tomten.jpg" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/storasjöfallet.jpg" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup21 = folium.Popup("""<h2>Destination 21 Kiruna</h2><br/>
              Kiruna is the northernmost city in Sweden. In a Sami village by Lake Luossajaure, Nils learns about Sami culture. Laponia is definitely my favorite part of Sweden. If you are here I can definitely recommend to get to know the Sami culture. Also, you should definitely take the chance to listen to the sounds of a joik.<br/>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/P7130388.JPG" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/P7140419.JPG" alt="Trulli" style="max-width:100%;max-height:100%">
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/P7140428.JPG" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=1000)

popup22 = folium.Popup("""<h2>Destination 22 Härjedalen</h2><br/>
              When Nils and the geese pass Härjedalen, the weather is foggy, and Nils only learns about the province through the stories of his companions. He concludes that it is unsuitable for human inhabitants, who should leave the provinces to nature. It is the least populated province in Sweden. <br/>
              """, max_width=500)

popup23 = folium.Popup("""<h2>Destination 23 Östersund</h2><br/>
              Östersund is the only city in Jämtland, and its economic and political center. The city is famous for its location to nearby nature and for its winter activities. The city is located approximately in the center of Sweden. The geographic center of Sweden, by the way, is on Flataklocken, a mountain in the Medelpad landscape, west of Sundsvall.<br/>
              """, max_width=500)

popup24 = folium.Popup("""<h2>Destination 24 Mårbacka</h2><br/>
              Selma Lagerlöf, one of the world's most famous writers, grew up on Mårbacka. Even as a young girl, she wanted to be a writer.<br/>
              <a href="https://marbacka.com/en/" target="_blank">Learn more about Selma Lagerlöf</a>""", max_width=500)

popup25 = folium.Popup("""<h2>Destination 25 Väderöarna</h2><br/>
              I can highly to recommend You can hike wonderfully over the countless archipelagos. In addition, a side trip to Tanumshede is recommended. Around Tanumshede many ancient rock paintings have been found.<br/>
              <a href="https://www.vitlyckemuseum.se/en/"target="_blank">Learn more about the world of the Bronze Age</a>
              <img src="https://raw.githubusercontent.com/Leonieen/Resume/main/pictures/Väderöarna.JPG" alt="Trulli" style="max-width:100%;max-height:100%">""", max_width=500)

popup26 = folium.Popup("""<h2>Destination 26 Nääs Slott</h2><br/>
              Nääs is Sweden's best-preserved manor from the late 19th century, one of Sweden's largest providers of arts and crafts courses, and a place where people have always come together to create lifelong memories. Selma Lagerlöf spent many of her summers here.<br/>
              <a href="https://uk.naas.se/"target="_blank">Learn more about Nääs Slott</a>""", max_width=500)

# %%
url = (
    "C:/Users/leoni/Documents/Uni/Eigene Projekte/NilsHolgersson"
)
inseln = f"{url}/2009-2010Baltic_explanatoryVariables.csv"
df = pd.read_csv(inseln)

col_list1 = ["groupX", "groupY"]
islands_pos = pd.read_csv(inseln, usecols=col_list1)
islands = islands_pos.values

m.add_child(plugins.HeatMap(islands, radius=20))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Marker1 Västra Vemmenhö
folium.vector_layers.Marker(location=[55.427336,13.470896], icon=icon1, tooltip='Västra Vemmenhög', popup=popup1).add_to(m)
#Marker 2
folium.vector_layers.Marker(location=[55.854861,14.133912], icon=icon2, tooltip='Vittskövle Slott', popup=popup2).add_to(m)
#Marker 3
folium.vector_layers.Marker(location=[55.500640,14.230456], icon=icon3, tooltip='Glimmingehus', popup=popup3).add_to(m)
#Marker 4
folium.vector_layers.Marker(location=[56.301716,12.452369], icon=icon4, tooltip='Kullaberg', popup=popup4).add_to(m)
#Marker 5
folium.vector_layers.Marker(location=[56.161035,15.586339], icon=icon5, tooltip='Karlskrona', popup=popup5).add_to(m)
#Marker 6
folium.vector_layers.Marker(location=[56.664756,16.634820], icon=icon6, tooltip='Öland', popup=popup6).add_to(m)
#Marker 7
folium.vector_layers.Marker(location=[57.466102,18.490626], icon=icon7, tooltip='Gotland', popup=popup7).add_to(m)
#Marker 8
folium.vector_layers.Marker(location=[57.733037,15.761353], icon=icon8, tooltip='Småland', popup=popup8).add_to(m)
#Marker 9
folium.vector_layers.Marker(location=[58.660557,16.399143], icon=icon9, tooltip='Kolmården', popup=popup9).add_to(m)
#Marker 10
folium.vector_layers.Marker(location=[58.971568,16.215160], icon=icon10, tooltip='Stora Djulö', popup=popup10).add_to(m)
#Marker 11
folium.vector_layers.Marker(location=[59.244360,15.275398], icon=icon11, tooltip='Närke', popup=popup11).add_to(m)
#Marker 12
folium.vector_layers.Marker(location=[59.966808,16.008792], icon=icon12, tooltip='Bergslagen', popup=popup12).add_to(m)
#Marker 13
folium.vector_layers.Marker(location=[60.606487,15.635294], icon=icon13, tooltip='Falun', popup=popup13).add_to(m)
#Marker 14
folium.vector_layers.Marker(location=[60.889903,14.664823], icon=icon14, tooltip='Siljansbygden', popup=popup14).add_to(m)
#Marker 15
folium.vector_layers.Marker(location=[59.858429,17.638921], icon=icon15, tooltip='Uppsala', popup=popup15).add_to(m)
#Marker 16
folium.vector_layers.Marker(location=[59.386780,18.722948], icon=icon16, tooltip='Stockholm archipelago', popup=popup16).add_to(m)
#Marker 17
folium.vector_layers.Marker(location=[59.329245,18.068461], icon=icon17, tooltip='Stockholm', popup=popup17).add_to(m)
#Marker 18
folium.vector_layers.Marker(location=[61.800453,16.582614], icon=icon18, tooltip='Delsbo, Hudiksvall', popup=popup18).add_to(m)
#Marker 19
folium.vector_layers.Marker(location=[63.159757,17.246508], icon=icon19, tooltip='Västernorrland County', popup=popup19).add_to(m)
#Marker 20
folium.vector_layers.Marker(location=[67.137659,20.659646], icon=icon20, tooltip='Gällivare', popup=popup20).add_to(m)
#Marker 21
folium.vector_layers.Marker(location=[67.855770,20.225252], icon=icon21, tooltip='Kiruna', popup=popup21).add_to(m)
#Marker 22
folium.vector_layers.Marker(location=[62.271015,13.810314], icon=icon22, tooltip='Härjedalen', popup=popup22).add_to(m)
#Marker 23
folium.vector_layers.Marker(location=[63.183161,14.597231], icon=icon23, tooltip='Östersund', popup=popup23).add_to(m)
#Marker 24
folium.vector_layers.Marker(location=[59.780460,13.232316], icon=icon24, tooltip='Mårbacka', popup=popup24).add_to(m)
#Marker 25
folium.vector_layers.Marker(location=[58.578334,11.066847], icon=icon25, tooltip='Väderöarna', popup=popup25).add_to(m)
#Marker 26
folium.vector_layers.Marker(location=[57.816158,12.400513], icon=icon26, tooltip='Nääs Slott', popup=popup26).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("nilsmap1.html")

# %%
lat_lng_points = [[55.427336,13.470896],
                  [55.854861,14.133912],
                  [55.500640,14.230456],
                  [56.301716,12.452369],
                  [56.161035,15.586339],
                  [56.664756,16.634820],
                  [57.466102,18.490626],
                  [57.733037,15.761353],
                  [58.660557,16.399143],
                  [58.971568,16.215160],
                  [59.244360,15.275398],
                  [59.966808,16.008792],
                  [60.606487,15.635294],
                  [60.889903,14.664823],
                  [59.858429,17.638921],
                  [59.386780,18.722948],
                  [59.329245,18.068461],
                  [61.800453,16.582614],
                  [63.159757,17.246508],
                  [67.137659,20.659646],
                  [67.855770,20.225252],
                  [62.271015,13.810314],
                  [63.183161,14.597231],
                  [59.780460,13.232316],
                  [58.578334,11.066847],
                  [57.816158,12.400513],]
folium.PolyLine(locations=lat_lng_points,
                color="blue",
                tooltip="PolyLine",
                weight=5,  # line thickness
                opacity=0.8  # transparency
                ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("nilsmap2.html")

# %%
m2 = folium.Map(location=[61.800453,16.582614], zoom_start=5)

# Lon, Lat order.
lines = [
    {
        "coordinates": [
            [13.470896,55.427336],
            [14.133912,55.854861],
        ],
        "dates": ["2017-06-02T00:00:00", "2017-06-02T00:10:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [14.133912,55.854861],
            [14.230456,55.500640],
        ],
        "dates": ["2017-06-02T00:10:00", "2017-06-02T00:20:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [14.230456,55.500640],
            [12.452369,56.301716],
        ],
        "dates": ["2017-06-02T00:20:00", "2017-06-02T00:30:00"],
        "color": "blue",
        #"weight": 15,
    },
    {
        "coordinates": [
            [12.452369,56.301716],
            [15.586339,56.161035],
        ],
        "dates": ["2017-06-02T00:30:00", "2017-06-02T00:40:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [15.586339,56.161035],
            [16.634820,56.664756],
        ],
        "dates": ["2017-06-02T00:40:00", "2017-06-02T00:50:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [16.634820,56.664756],
            [18.490626,57.466102],
        ],
        "dates": ["2017-06-02T00:50:00", "2017-06-02T01:00:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [18.490626,57.466102],
            [15.761353,57.733037],
        ],
        "dates": ["2017-06-02T01:00:00", "2017-06-02T01:10:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [15.761353,57.733037],
            [16.399143,58.660557],
        ],
        "dates": ["2017-06-02T01:10:00", "2017-06-02T01:20:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [16.399143,58.660557],
            [16.215160,58.971568],
        ],
        "dates": ["2017-06-02T01:20:00", "2017-06-02T01:30:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [16.215160,58.971568],
            [15.275398,59.244360],
        ],
        "dates": ["2017-06-02T01:30:00", "2017-06-02T01:40:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [15.275398,59.244360],
            [16.008792,59.966808],
        ],
        "dates": ["2017-06-02T01:40:00", "2017-06-02T01:50:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [16.008792,59.966808],
            [15.635294,60.606487],
        ],
        "dates": ["2017-06-02T01:50:00", "2017-06-02T02:00:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [15.635294,60.606487],
            [14.664823,60.889903],
        ],
        "dates": ["2017-06-02T02:00:00", "2017-06-02T02:10:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [14.664823,60.889903],
            [17.638921,59.858429],
        ],
        "dates": ["2017-06-02T02:10:00", "2017-06-02T02:20:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [17.638921,59.858429],
            [18.722948,59.386780],
        ],
        "dates": ["2017-06-02T02:20:00", "2017-06-02T02:30:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [18.722948,59.386780],
            [18.068461,59.329245],
        ],
        "dates": ["2017-06-02T02:30:00", "2017-06-02T02:40:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [18.068461,59.329245],
            [16.582614,61.800453],
        ],
        "dates": ["2017-06-02T02:40:00", "2017-06-02T02:50:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [16.582614,61.800453],
            [17.246508,63.159757],
        ],
        "dates": ["2017-06-02T02:50:00", "2017-06-02T03:00:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [17.246508,63.159757],
            [20.659646,67.137659],
        ],
        "dates": ["2017-06-02T03:00:00", "2017-06-02T03:10:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [20.659646,67.137659],
            [20.225252,67.855770],
        ],
        "dates": ["2017-06-02T03:10:00", "2017-06-02T03:20:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [20.225252,67.855770],
            [13.810314,62.271015],
        ],
        "dates": ["2017-06-02T03:20:00", "2017-06-02T03:30:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [13.810314,62.271015],
            [14.597231,63.183161],
        ],
        "dates": ["2017-06-02T03:30:00", "2017-06-02T03:40:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [14.597231,63.183161],
            [13.232316,59.780460],
        ],
        "dates": ["2017-06-02T03:40:00", "2017-06-02T03:50:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [13.232316,59.780460],
            [11.066847,58.578334],
        ],
        "dates": ["2017-06-02T03:50:00", "2017-06-02T04:00:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [11.066847,58.578334],
            [12.400513,57.816158],
        ],
        "dates": ["2017-06-02T04:00:00", "2017-06-02T04:10:00"],
        "color": "blue",
    },
    {
        "coordinates": [
            [12.400513,57.816158],
            [13.470896,55.427336],
        ],
        "dates": ["2017-06-02T04:10:00", "2017-06-02T04:20:00"],
        "color": "blue",
    },
]

features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "LineString",
            "coordinates": line["coordinates"],
        },
        "properties": {
            "times": line["dates"],
            "style": {
                "color": line["color"],
                "weight": line["weight"] if "weight" in line else 5,
            },
        },
    }
    for line in lines
]

plugins.TimestampedGeoJson(
    {
        "type": "FeatureCollection",
        "features": features,
    },
    period="PT1M",
    add_last_point=True,
).add_to(m2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m2.save("nilsmap3.html")

# %%
url = (
    "C:/Users/leoni/Documents/Uni/Eigene Projekte/NilsHolgersson"
)
inseln = f"{url}/2009-2010Baltic_explanatoryVariables.csv"
df = pd.read_csv(inseln)
df
# Out:
#     islandID Island  speciesRichness     groupX     groupY        Decimal  \
# 0        A01      A              196  59.486400  18.983320  381113.910000
# 1        A02      A               80  59.491643  18.989755   30559.472900
# 2        A03      A               48  59.482083  18.974522    8050.942821
# 3        A06      A               15  59.489871  18.985391     227.335138
# 4        A07      A               33  59.490420  18.985933    1308.956805
# ..       ...    ...              ...        ...        ...            ...
# 107      M01      M              208  58.988462  18.447831  365674.690700
# 108      M02      M               31  58.985859  18.452063    1918.368524
# 109      M03      M               32  58.985276  18.453032    2056.740620
# 110      M06      M               28  58.986038  18.446038     687.679722
# 111      M08      M               29  58.985569  18.444424     677.794499
#
#      Degrees  (WGS84)  Island Area, square metres  Island Height, metres  ...  \
# ...

# %%
m3 = folium.Map(location=[59.486400,18.983320], zoom_start=9)

# for index, location_info in df.iterrows():
#     folium.Marker([location_info["groupX"], location_info["groupY"]], popup=location_info["islandID"]).add_to(m3)
#     folium.vector_layers.CircleMarker(
#             location=[location_info['groupX'], location_info['groupY']], 
#             radius=location_info['speciesRichness']/10,
#             color='#3186cc',
#             fill_color='#3186cc'
#         ).add_to(m3)
    
col_list1 = ["groupX", "groupY"]
islands_pos = pd.read_csv(inseln, usecols=col_list1)
islands = islands_pos.values

m3.add_child(plugins.HeatMap(islands, radius=20))
    
m3.save('HeatStockholm.html')
